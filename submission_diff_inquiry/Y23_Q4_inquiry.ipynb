# %% [markdown]
# # Biosample Diff Q4 vs Q3

# %%
import sqlite3
import pandas as pd

DB1, DB2 = 'q3', 'q4'

# %%
db1_conn = sqlite3.connect(f'{DB1}.db')
db2_conn = sqlite3.connect(f'{DB2}.db')

# %%
query = f"""
select *
from biosample
"""

db1_biosample_df = pd.read_sql_query(query,db1_conn)

# %%
query = f"""
select * 
from biosample
"""

db2_biosample_df = pd.read_sql_query(query,db2_conn)

# %%
unique_count_db1 = db1_biosample_df['local_id'].nunique()
unique_count_db2 = db2_biosample_df['local_id'].nunique()
unique_count_db2 - unique_count_db1
# Out:
# -55977

# %%
missing_in_q4 = db1_biosample_df[~db1_biosample_df['local_id'].isin(db2_biosample_df['local_id'])]
missing_in_q4
# Out:
#       id_namespace     local_id project_id_namespace project_local_id  \
# 0       kidsfirst:  BS_0000QNBM           kidsfirst:      SD_BHJXBDQK
# 1       kidsfirst:  BS_000KK0N8           kidsfirst:      SD_BHJXBDQK
# 2       kidsfirst:  BS_0014X1NM           kidsfirst:      SD_BHJXBDQK
# 3       kidsfirst:  BS_0024M38B           kidsfirst:      SD_BHJXBDQK
# 5       kidsfirst:  BS_0032YCBC           kidsfirst:      SD_BHJXBDQK
# ...            ...          ...                  ...              ...
# 96672   kidsfirst:  BS_ZZWBSQBJ           kidsfirst:      SD_BHJXBDQK
# 96675   kidsfirst:  BS_ZZWSZ8KA           kidsfirst:      SD_BHJXBDQK
# 96676   kidsfirst:  BS_ZZX0PF6K           kidsfirst:      SD_BHJXBDQK
# 96678   kidsfirst:  BS_ZZY5HXJ5           kidsfirst:      SD_BHJXBDQK
# 96681   kidsfirst:  BS_ZZZS6T4R           kidsfirst:      SD_BHJXBDQK
#
#       persistent_id               creation_time sample_prep_method  \
# 0              None  2020-11-20 22:12:45.415083               None
# 1              None  2020-11-20 22:13:16.175450               None
# 2              None  2020-11-20 22:24:20.797484               None
# 3              None  2022-01-07 18:19:09.695777               None
# 5              None  2020-12-07 22:52:14.660365               None
# ...             ...                         ...                ...
# 96672          None  2021-03-08 19:37:07.712360               None
# 96675          None  2021-03-08 19:19:30.798283               None
# 96676          None  2020-11-20 22:32:46.178836               None
# 96678          None  2020-11-20 22:38:50.801892               None
# 96681          None  2020-11-20 22:13:23.907727               None
#
#               anatomy
# 0                None
# 1                None
# 2                None
# 3                None
# 5      UBERON:0000955
# ...               ...
# 96672  UBERON:0000955
# 96675  UBERON:0000955
# 96676            None
# 96678  UBERON:0000955
# 96681            None
#
# [56891 rows x 8 columns]

# %%
study_info_df = pd.read_sql_query("select * from project",db2_conn)

studies_losing_biosamples = pd.DataFrame({'project_local_id': missing_in_q4['project_local_id'].unique()})

studies_losing_biosamples = study_info_df.merge(studies_losing_biosamples,
                                                how='inner',
                                                left_on='local_id',
                                                right_on='project_local_id')

studies_losing_biosamples
# Out:
#   id_namespace     local_id persistent_id creation_time abbreviation  \
# 0   kidsfirst:  SD_Z6MWD3H0          None          None  SD_Z6MWD3H0
# 1   kidsfirst:  SD_NMVV8A1Y          None          None  SD_NMVV8A1Y
# 2   kidsfirst:  SD_BHJXBDQK          None          None  SD_BHJXBDQK
# 3   kidsfirst:  SD_AQ9KVN5P          None          None  SD_AQ9KVN5P
# 4   kidsfirst:  SD_8Y99QZJJ          None          None  SD_8Y99QZJJ
#
#                                                 name  \
# 0  Kids First: Leukemia & Heart Defects in Down S...
# 1       Kids First: Kidney and Urinary Tract Defects
# 2                 Pediatric Brain Tumor Atlas: CBTTC
# 3                             Kids First: T Cell ALL
# 4                  Pediatric Brain Tumor Atlas: PNOC
#
#                                          description project_local_id
# 0  Kids First: Genomic Analysis of Congenital Hea...      SD_Z6MWD3H0
# 1  Kids First: Genetics of Structural Defects of ...      SD_NMVV8A1Y
# 2  Pediatric Brain Tumor Atlas - Children's Brain...      SD_BHJXBDQK
# 3  Comprehensive Genomic Profiling to Improve Pre...      SD_AQ9KVN5P
# 4                  Pediatric Brain Tumor Atlas: PNOC      SD_8Y99QZJJ

# %%
missing_in_q4_with_anatomy = missing_in_q4[~missing_in_q4['anatomy'].isnull()]
missing_in_q4_without_anatomy = missing_in_q4[missing_in_q4['anatomy'].isnull()]

# %%
missing_anatomy_count = missing_in_q4_with_anatomy.groupby("project_local_id") \
                                                    .agg(bio_anatomy_count=('local_id', 'size'))

# %%
missing_without_anatomy_count = missing_in_q4_without_anatomy.groupby("project_local_id") \
                                                    .agg(bio_without_anatomy_count=('local_id','size'))

# %%
study_anatomy_breakdown = missing_anatomy_count.merge(missing_without_anatomy_count,
                                                           how='outer',
                                                           on='project_local_id')

study_anatomy_breakdown = study_anatomy_breakdown.fillna(0).astype(int)
study_anatomy_breakdown
# Out:
#                   bio_anatomy_count  bio_without_anatomy_count
# project_local_id
# SD_8Y99QZJJ                      14                         22
# SD_BHJXBDQK                   38500                      18262
# SD_AQ9KVN5P                       0                         74
# SD_NMVV8A1Y                       0                          4
# SD_Z6MWD3H0                       0                         15
